# %%
import cv2
import matplotlib.pyplot as plt
path_to_pic = 'labelled_dataset/m501_0.jpg'
img1 = cv2.imread(path_to_pic)
img1_modified = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
#show the image
plt.imshow(img1_modified)
plt.show()

# %%
import easyocr
reader = easyocr.Reader(lang_list=['en'])
results = reader.readtext(path_to_pic)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
print(results)
# Out:
# [([[109, 343], [265, 343], [265, 483], [109, 483]], '1', 0.5819881186636486), ([[0, 435], [81, 435], [81, 519], [0, 519]], 'B', 0.9959838264495033), ([[316.54517042775547, 269.05045415967874], [1033.540120827183, -4.547474241920751], [1074.4548295722445, 166.9495458403213], [357.45987917281707, 440.5474742419207]], 'CFE:144', 0.4511449488548636)]

# %%
import cv2
import easyocr

# Initialize EasyOCR reader and read the image
reader = easyocr.Reader(lang_list=['en'])
results = reader.readtext(path_to_pic)

# Read the original image
img = cv2.imread(path_to_pic)

# Draw bounding boxes
for (bbox, text, prob) in results:
    top_left = tuple(map(int, bbox[0]))
    bottom_right = tuple(map(int, bbox[2]))
    cv2.rectangle(img, top_left, bottom_right, (0, 255, 0), 2)

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imshow('License Plate with Bounding Boxes', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\au616584\OneDrive - Aarhus Universitet\Datalogi\Deep_learning\license_plate_recognition_glue\initial_try.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/au616584/OneDrive%20-%20Aarhus%20Universitet/Datalogi/Deep_learning/license_plate_recognition_glue/initial_try.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a>     cv2.rectangle(img, top_left, bottom_right, (0, 255, 0), 2)
#      <a href='vscode-notebook-cell:/c%3A/Users/au616584/OneDrive%20-%20Aarhus%20Universitet/Datalogi/Deep_learning/license_plate_recognition_glue/initial_try.ipynb#W4sZmlsZQ%3D%3D?line=16'>17</a> img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# ...

# %%
# !pip uninstall opencv-python
# Out:
# ^C

# %%
from ultralytics import YOLO
from PIL import Image
# Load a model
model = YOLO('yolov8n.pt')  # load an official model
# model = YOLO('path/to/best.pt')  # load a custom model

# Predict with the model
results = model(path_to_pic)  # predict on an image
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results.jpg')  # save image
# Out:
# image 1/1 c:\Users\au616584\OneDrive - Aarhus Universitet\Datalogi\Deep_learning\license_plate_recognition_glue\labelled_dataset\m501_0.jpg: 352x640 1 train, 122.6ms
# Speed: 2.0ms preprocess, 122.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)

# %%
print(results)
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...
